# %%
# !conda activate project
# Out:
# 'conda'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# !pip install -r requirements.txt
# Out:
# ^C
# ...
#      ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#       --------------------------------------- 0.1/5.1 MB 2.0 MB/s eta 0:00:03
#      - -------------------------------------- 0.2/5.1 MB 1.8 MB/s eta 0:00:03
#      - -------------------------------------- 0.2/5.1 MB 1.8 MB/s eta 0:00:03
#      -- ------------------------------------- 0.4/5.1 MB 2.0 MB/s eta 0:00:03
#      --- ------------------------------------ 0.4/5.1 MB 1.9 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.5/5.1 MB 2.0 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.6/5.1 MB 2.1 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.7/5.1 MB 1.9 MB/s eta 0:00:03
#      ------ --------------------------------- 0.8/5.1 MB 1.9 MB/s eta 0:00:03
#      ------- -------------------------------- 0.9/5.1 MB 2.0 MB/s eta 0:00:03
#      ------- -------------------------------- 1.0/5.1 MB 2.0 MB/s eta 0:00:03
# ...
